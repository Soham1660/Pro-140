# %% [markdown]
# <a href="https://colab.research.google.com/github/Darksoul913/Pro-C140/blob/main/Pro_C141.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-ab14f8e3-7522-4fc5-a22d-0b5cd3ae1a54" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ab14f8e3-7522-4fc5-a22d-0b5cd3ae1a54">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle (1).json
# {'kaggle.json': b'{"username":"siddheshamrutkar","key":"30e01802f50c6ff984bb792686f6aa81"}'}

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d gspmoreira/articles-sharing-reading-from-cit-deskdrop
# Out:
# articles-sharing-reading-from-cit-deskdrop.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip articles-sharing-reading-from-cit-deskdrop.zip
# Out:
# Archive:  articles-sharing-reading-from-cit-deskdrop.zip
# replace shared_articles.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: shared_articles.csv
# replace users_interactions.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: users_interactions.csv

# %%
# !ls
# Out:
#  articles-sharing-reading-from-cit-deskdrop.zip   sample_data
# 'kaggle (1).json'				  shared_articles.csv
#  kaggle.json					  users_interactions.csv

# %%
import pandas as pd 
import numpy as np 

df1=pd.read_csv('shared_articles.csv')
df2=pd.read_csv('users_interactions.csv')

# %%
df1.head()
# Out:
#                   timestamp            contentId       authorPersonId  \
# eventType
# CONTENT REMOVED  1459192779 -6451309518266745024  4340306774493623681
# CONTENT SHARED   1459193988 -4110354420726924665  4340306774493623681
# CONTENT SHARED   1459194146 -7292285110016212249  4340306774493623681
# CONTENT SHARED   1459194474 -6151852268067518688  3891637997717104548
# CONTENT SHARED   1459194497  2448026894306402386  4340306774493623681
#
#                      authorSessionId authorUserAgent authorRegion  \
# eventType
# CONTENT REMOVED  8940341205206233829             NaN          NaN
# CONTENT SHARED   8940341205206233829             NaN          NaN
# CONTENT SHARED   8940341205206233829             NaN          NaN
# CONTENT SHARED  -1457532940883382585             NaN          NaN
# CONTENT SHARED   8940341205206233829             NaN          NaN
#
#                 authorCountry contentType  \
# eventType
# CONTENT REMOVED           NaN        HTML
# ...

# %%
df2.head()
# Out:
#     timestamp eventType            contentId             personId  \
# 0  1465413032      VIEW -3499919498720038879 -8845298781299428018
# 1  1465412560      VIEW  8890720798209849691 -1032019229384696495
# 2  1465416190      VIEW   310515487419366995 -1130272294246983140
# 3  1465413895    FOLLOW   310515487419366995   344280948527967603
# 4  1465412290      VIEW -7820640624231356730  -445337111692715325
#
#              sessionId                                          userAgent  \
# 0  1264196770339959068                                                NaN
# 1  3621737643587579081  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2...
# 2  2631864456530402479                                                NaN
# 3 -3167637573980064150                                                NaN
# 4  5611481178424124714                                                NaN
#
#   userRegion userCountry
# 0        NaN         NaN
# 1         NY          US
# 2        NaN         NaN
# ...

# %%
df1 = df1[df1['eventType'] == 'CONTENT SHARED']
df1.head()
# Out:
#     timestamp       eventType            contentId       authorPersonId  \
# 1  1459193988  CONTENT SHARED -4110354420726924665  4340306774493623681
# 2  1459194146  CONTENT SHARED -7292285110016212249  4340306774493623681
# 3  1459194474  CONTENT SHARED -6151852268067518688  3891637997717104548
# 4  1459194497  CONTENT SHARED  2448026894306402386  4340306774493623681
# 5  1459194522  CONTENT SHARED -2826566343807132236  4340306774493623681
#
#        authorSessionId authorUserAgent authorRegion authorCountry contentType  \
# 1  8940341205206233829             NaN          NaN           NaN        HTML
# 2  8940341205206233829             NaN          NaN           NaN        HTML
# 3 -1457532940883382585             NaN          NaN           NaN        HTML
# 4  8940341205206233829             NaN          NaN           NaN        HTML
# 5  8940341205206233829             NaN          NaN           NaN        HTML
#
#                                                  url  \
# ...

# %%
df1.shape
# Out:
# (3122, 12)

# %%
def find_total_events(df1_row):
  totalView = df2[(df2['contentId'] == df1_row['contentId']) & df2['eventType'] == 'VIEW'].shape[0]
  totalLike = df2[(df2['contentId'] == df1_row['contentId']) & df2['eventType'] == 'LIKE'].shape[0]
  totalBookmark = df2[(df2['contentId'] == df1_row['contentId']) & df2['eventType'] == 'BOOKMARK'].shape[0]
  totalFollow = df2[(df2['contentId'] == df1_row['contentId']) & df2['eventType'] == 'FOLLOW'].shape[0]
  totalComments = df2[(df2['contentId'] == df1_row['contentId']) & df2['eventType'] == 'COMMENT CREATED'].shape[0]
  return totalView + totalLike + totalBookmark + totalFollow + totalComments
df1['total_events'] = df1.apply(total_events, axis=1)

# %%
print(df1.head(50))

# %%
df1=df1.sort_values(['total_events'],ascending=False)
df1.head()
# Out:
#        timestamp       eventType            contentId       authorPersonId  \
# 1     1459193988  CONTENT SHARED -4110354420726924665  4340306774493623681
# 2093  1471477815  CONTENT SHARED -5283009029345397378  4209517478660372522
# 2084  1471366025  CONTENT SHARED -5850390492300666299  7645894863578715801
# 2085  1471374783  CONTENT SHARED -7165716941095296287 -1032019229384696495
# 2086  1471431177  CONTENT SHARED -5649504870272917833  2682799999279860984
#
#           authorSessionId authorUserAgent authorRegion authorCountry  \
# 1     8940341205206233829             NaN          NaN           NaN
# 2093  5185454684179635438             NaN          NaN           NaN
# 2084  6107910099552275355             NaN          NaN           NaN
# 2085   880025729283447629             NaN          NaN           NaN
# 2086 -5776940196792685042             NaN          NaN           NaN
#
#      contentType                                                url  \
# ...

# %%
df1 = df1.sort_values(['total_events'], ascending=[False])
df1.head()
# Out:
#      timestamp       eventType            contentId       authorPersonId  \
# 1   1459193988  CONTENT SHARED -4110354420726924665  4340306774493623681
# 11  1459217624  CONTENT SHARED  1805789466376069146 -1032019229384696495
# 12  1459217735  CONTENT SHARED -2081760549863309770 -1032019229384696495
# 3   1459194474  CONTENT SHARED -6151852268067518688  3891637997717104548
# 4   1459194497  CONTENT SHARED  2448026894306402386  4340306774493623681
#
#         authorSessionId authorUserAgent authorRegion authorCountry  \
# 1   8940341205206233829             NaN          NaN           NaN
# 11  3042342415047984532             NaN          NaN           NaN
# 12  3042342415047984532             NaN          NaN           NaN
# 3  -1457532940883382585             NaN          NaN           NaN
# 4   8940341205206233829             NaN          NaN           NaN
#
#    contentType                                                url  \
# ...

# %%
def convert_lowercase(x):
  if isinstance(x, str):
      return x.lower()
  else:
      return ''

df1["title"] = df1["title"].apply(convert_lowercase)
df1.head()
# Out:
#      timestamp       eventType            contentId       authorPersonId  \
# 1   1459193988  CONTENT SHARED -4110354420726924665  4340306774493623681
# 11  1459217624  CONTENT SHARED  1805789466376069146 -1032019229384696495
# 12  1459217735  CONTENT SHARED -2081760549863309770 -1032019229384696495
# 3   1459194474  CONTENT SHARED -6151852268067518688  3891637997717104548
# 4   1459194497  CONTENT SHARED  2448026894306402386  4340306774493623681
#
#         authorSessionId authorUserAgent authorRegion authorCountry  \
# 1   8940341205206233829             NaN          NaN           NaN
# 11  3042342415047984532             NaN          NaN           NaN
# 12  3042342415047984532             NaN          NaN           NaN
# 3  -1457532940883382585             NaN          NaN           NaN
# 4   8940341205206233829             NaN          NaN           NaN
#
#    contentType                                                url  \
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
count = CountVectorizer(stop_words='english')
count_matrix = count.fit_transform(df1['title'])

# %%
from sklearn.metrics.pairwise import cosine_similarity
cosine_sim2 = cosine_similarity(count_matrix, count_matrix)

# %%
df1 = df1.reset_index()
indices = pd.Series(df1.index, index=df1['contentId'])

# %%
def get_recommendations(contentId, cosine_sim):
    idx = indices[contentId]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:11]
    movie_indices = [i[0] for i in sim_scores]
    return df1['contentId'].iloc[movie_indices]

# %%
get_recommendations(-4029704725707465084, cosine_sim2)
# Out:
# 2418     174707786647990372
# 2449    5087084654882097891
# 137     8298709454703868984
# 262    -5679427141235752819
# 582     4118743389464105405
# 803     4625350031392752392
# 909      -39485845307123560
# 1623    5338677278233757627
# 2780    7088167897470452815
# 231    -8587352636561360574
# Name: contentId, dtype: int64

# %%
from google.colab import files

df1.to_csv('articles.csv')
files.download('articles.csv')
